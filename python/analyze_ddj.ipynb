# %% [markdown]
# # Evaluate Mawangdui Text

# %%
from collections import Counter

# Define the file path
file_path = r"..\public\docs\ddj_guodian_chu.txt"  # Adjust if needed

# Read the file content
with open(file_path, "r", encoding="utf-8") as file:
    text = file.read()

# Count character occurrences
char_counts = Counter(text)

# Sort by frequency in descending order
sorted_chars = sorted(char_counts.items(), key=lambda x: x[1], reverse=True)

# Display results
for char, count in sorted_chars:
    print(f"'{char}': {count}")
# Out:
# '，': 606
# '。': 387
# '之': 250
# '不': 239
# '以': 159
# '；': 154
# '其': 142
# '而': 119
# '为': 114
# '无': 100
# '者': 92
# '天': 92
# '人': 85
# '　': 82
# '章': 81
# '有': 81
# '
# ': 81
# '下': 80
# '十': 76
# '道': 75
# '是': 68
# '故': 67
# '大': 57
# '知': 56
# '善': 50
# '于': 48
# '德': 47
# '若': 46
# '也': 41
# '生': 36
# '可': 35
# '？': 35
# '物': 34
# '民': 32
# '则': 32
# '自': 32
# '谓': 31
# '得': 31
# '能': 31
# '圣': 30
# '夫': 30
# '三': 29
# '兮': 29
# '常': 28
# '所': 26
# '一': 23
# '欲': 23
# '身': 23
# '将': 23
# '名': 22
# '用': 22
# '吾': 22
# '二': 21
# '事': 21
# '强': 21
# '四': 21
# '五': 21
# '足': 21
# '言': 20
# '贵': 20
# '莫': 20
# '曰': 20
# '成': 19
# '行': 19
# '六': 19
# '我': 19
# '万': 18
# '或': 18
# '地': 18
# '死': 18
# '七': 18
# '上': 18
# '此': 16
# '长': 16
# '国': 16
# '失': 16
# '唯': 15
# '信': 15
# '胜': 15
# '相': 14
# '见': 14
# '与': 14
# '何': 14
# '必': 14
# '居': 13
# '治': 13
# '多': 13
# '处': 13
# '明': 13
# '取': 13
# '乃': 13
# '谷': 12
# '器': 12
# '“': 12
# '”': 12
# '亦': 12
# '兵': 12
# '邦': 12
# ...

# %%
print(len(sorted_chars))
# Out:
# 839

# %%
import matplotlib.pyplot as plt
from matplotlib import rcParams

# Set the font family to a font that supports Chinese characters
rcParams['font.family'] = 'SimSun'
rcParams['axes.unicode_minus'] = False  # Ensure minus sign is displayed correctly

meaningful_list = '道德大常不下知生死天地自圣王人民无有为'

# Extract characters and counts
characters = [char for char, count in sorted_chars if char in meaningful_list]
counts = [count for char, count in sorted_chars if char in meaningful_list]

# Plot the histogram
plt.figure(figsize=(12, 6), dpi=300)
plt.bar(characters, counts, color='#0F766E')
plt.title('Character Frequency', fontsize=16, fontfamily='Georgia')
# plt.xlabel('Characters', fontsize=14, fontfamily='Georgia')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.ylabel('Number of Occurrences', fontsize=14, fontfamily='Georgia')
plt.gca().set_xlim(left=-0.5, right=len(meaningful_list) - 0.5)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.show()

# %% [markdown]
# ## Occurrences of 不 in Mawangdui Text

# %%
from collections import Counter

# Define the file path
file_path = r"..\public\docs\ddj_guodian_chu.txt"  # Adjust if needed

# Read the file content
with open(file_path, "r", encoding="utf-8") as file:
    text = file.read()
    # Count the frequency of characters occurring after character '不'
    after_不_counts = Counter()
    for i in range(len(text) - 1):
        if text[i] == '不':
            after_不_counts[text[i + 1]] += 1

# Sort by frequency in descending order
after_不_sorted_chars = sorted(after_不_counts.items(), key=lambda x: x[1], reverse=True)

# Display results
for char, count in after_不_sorted_chars:
    print(f"'{char}': {count}")
# Out:
# '可': 19
# '足': 12
# '知': 10
# '争': 8
# '为': 8
# '自': 8
# '善': 7
# '敢': 7
# '见': 5
# '得': 5
# '欲': 5
# '言': 4
# '信': 4
# '殆': 4
# '道': 4
# '伤': 4
# '如': 3
# '有': 3
# '恃': 3
# '畏': 3
# '居': 3
# '离': 3
# '祥': 3
# '失': 3
# '害': 3
# '厌': 3
# '贵': 2
# '盈': 2
# '仁': 2
# '勤': 2
# '宰': 2
# '终': 2
# '行': 2
# '用': 2
# '忒': 2
# '割': 2
# '以': 2
# '处': 2
# '美': 2
# '谷': 2
# '克': 2
# '神': 2
# '相': 2
# '过': 2
# '肖': 2
# '病': 2
# '尚': 1
# '乱': 1
# '治': 1
# '屈': 1
# '死': 1
# '闻': 1
# '皦': 1
# '昧': 1
# '新': 1
# '怠': 1
# '和': 1
# '去': 1
# '能': 1
# '立': 1
# '明': 1
# '彰': 1
# '长': 1
# '改': 1
# '爱': 1
# '亡': 1
# '辞': 1
# '德': 1
# '笑': 1
# '辱': 1
# '弊': 1
# '穷': 1
# '出': 1
# '窥': 1
# '遇': 1
# '被': 1
# '尊': 1
# '救': 1
# '拔': 1
# '脱': 1
# '辍': 1
# '螫': 1
# '据': 1
# '搏': 1
# '嗄': 1
# '刿': 1
# '肆': 1
# '耀': 1
# '曰': 1
# '重': 1
# '武': 1
# '怒': 1
# '与': 1
# '我': 1
# '召': 1
# '然': 1
# '责': 1
# '远': 1
# '辩': 1
# '博': 1
# '积': 1

# %%
import matplotlib.pyplot as plt
from matplotlib import rcParams

# Set the font family to a font that supports Chinese characters
rcParams['font.family'] = 'SimSun'
rcParams['axes.unicode_minus'] = False  # Ensure minus sign is displayed correctly

meaningful_list = '道德大常下知生死天地自圣王人民无有为'

# Extract characters and counts
characters = [char for char, count in sorted_chars if char in meaningful_list]
counts = [count for char, count in sorted_chars if char in meaningful_list]

# Plot the histogram
plt.figure(figsize=(12, 6), dpi=300)
plt.bar(characters, counts, color='#0F766E')
plt.title('Character Frequency', fontsize=16, fontfamily='Georgia')
# plt.xlabel('Characters', fontsize=14, fontfamily='Georgia')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.ylabel('Number of Occurrences', fontsize=14, fontfamily='Georgia')
plt.gca().set_xlim(left=-0.5, right=len(meaningful_list) - 0.5)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.show()

# %% [markdown]
# 道 (dào) – "The Way" or "the Path"; central to Daoist philosophy.
# 德 (dé) – "Virtue" or "Power"; represents the active expression of the Dao.
# 大 (dà) – "Great" or "vast"; frequently used to describe the Dao and the natural order.
# 常 (cháng) - "constant," "eternal," "unchanging," or "in accordance with natural law." It is a key concept in Daoism, emphasizing the unchanging flow of the Dao.
# 不 (bù) – "Not" or "no"; frequently used in negations.
# 有 (yǒu) – "Being" or "existence"; often contrasted with wú to express the interplay of opposites.
# 下 (xià) – "Low" or "below"; often used metaphorically (e.g., rivers flowing downward).
# 知 (zhī) - "to know," "knowledge," or "wisdom," and it plays a crucial role in Daoist philosophy, often in contrast with deeper understanding or intuitive knowing.
# 生 (shēng) – "Life" or "to give birth"; central to Daoist ideas of nature and existence.
# 死 (sǐ) – "Death"; contrasts with shēng in discussions of the natural cycle.
# 自 (zì) – "Self" or "spontaneity"; related to ziran (自然), meaning "naturalness."
# 圣 (shèng) – "Sage" or "wise person"; describes the ideal ruler or enlightened individual.
# 王 (wáng) – "King" or "ruler"; reflects Daoist political philosophy.
# 人 (rén) – "Person" or "human"; used in discussions about governance and the sage.
# 民 (mín) – "People"; often mentioned in governance-related passages.
# 天 (tiān) – "Heaven" or "Nature"; often represents the cosmic order.
# 地 (dì) – "Earth"; complements tiān in describing the natural world.
# 无 (wú) – "Non-being" or "without"; key to the Daoist idea of emptiness and non-attachment.
# 为 (wéi) – "To act" or "to do"; central to the idea of wu wei (无为, non-action).
# 无为 (wú wéi) – "Non-action" or "effortless action"; a foundational Daoist principle.
# 道生 (dào shēng) – "The Dao gives birth"; a recurring phrase about creation.
# 天道 (tiān dào) – "The Way of Heaven"; a naturalistic concept in Daoism.

# %% [markdown]
# # Evaluate Standard Text

# %%
from collections import Counter

# Define the file path
file_path_std = r"..\public\docs\ddj_standard.txt"  # Adjust if needed

# Read the file content
with open(file_path_std, "r", encoding="utf-8") as file:
    text_std = file.read()

# Count character occurrences
char_counts_std = Counter(text_std)

# Sort by frequency in descending order
sorted_chars_std = sorted(char_counts_std.items(), key=lambda x: x[1], reverse=True)

# Display results
for char, count in sorted_chars:
    print(f"'{char}': {count}")
# Out:
# '，': 606
# '。': 387
# '之': 250
# '不': 239
# '以': 159
# '；': 154
# '其': 142
# '而': 119
# '为': 114
# '无': 100
# '者': 92
# '天': 92
# '人': 85
# '　': 82
# '章': 81
# '有': 81
# '
# ': 81
# '下': 80
# '十': 76
# '道': 75
# '是': 68
# '故': 67
# '大': 57
# '知': 56
# '善': 50
# '于': 48
# '德': 47
# '若': 46
# '也': 41
# '生': 36
# '可': 35
# '？': 35
# '物': 34
# '民': 32
# '则': 32
# '自': 32
# '谓': 31
# '得': 31
# '能': 31
# '圣': 30
# '夫': 30
# '三': 29
# '兮': 29
# '常': 28
# '所': 26
# '一': 23
# '欲': 23
# '身': 23
# '将': 23
# '名': 22
# '用': 22
# '吾': 22
# '二': 21
# '事': 21
# '强': 21
# '四': 21
# '五': 21
# '足': 21
# '言': 20
# '贵': 20
# '莫': 20
# '曰': 20
# '成': 19
# '行': 19
# '六': 19
# '我': 19
# '万': 18
# '或': 18
# '地': 18
# '死': 18
# '七': 18
# '上': 18
# '此': 16
# '长': 16
# '国': 16
# '失': 16
# '唯': 15
# '信': 15
# '胜': 15
# '相': 14
# '见': 14
# '与': 14
# '何': 14
# '必': 14
# '居': 13
# '治': 13
# '多': 13
# '处': 13
# '明': 13
# '取': 13
# '乃': 13
# '谷': 12
# '器': 12
# '“': 12
# '”': 12
# '亦': 12
# '兵': 12
# '邦': 12
# ...

# %%
import matplotlib.pyplot as plt
from matplotlib import rcParams

# Set the font family to a font that supports Chinese characters
rcParams['font.family'] = 'SimSun'
rcParams['axes.unicode_minus'] = False  # Ensure minus sign is displayed correctly

# Extract characters and counts
characters_std = [char for char, count in sorted_chars_std if char in meaningful_list]
counts_std = [count for char, count in sorted_chars_std if char in meaningful_list]

# Plot the histogram
plt.figure(figsize=(12, 6), dpi=300)
plt.bar(characters_std, counts_std, color='#0F766E')
plt.title('Character Frequency', fontsize=16, fontfamily='Georgia')
# plt.xlabel('Characters', fontsize=14, fontfamily='Georgia')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.ylabel('Number of Occurrences', fontsize=14, fontfamily='Georgia')
plt.gca().set_xlim(left=-0.5, right=len(meaningful_list) - 0.5)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.show()

# %% [markdown]
# # Compare Updated Text vs Standard Text

# %%
sorted_chars
# Out:
# [('，', 606),
#  ('。', 387),
#  ('之', 250),
#  ('不', 239),
#  ('以', 159),
#  ('；', 154),
#  ('其', 142),
#  ('而', 119),
#  ('为', 114),
#  ('无', 100),
#  ('者', 92),
#  ('天', 92),
#  ('人', 85),
#  ('\u3000', 82),
#  ('章', 81),
#  ('有', 81),
#  ('\n', 81),
#  ('下', 80),
#  ('十', 76),
#  ('道', 75),
#  ('是', 68),
#  ('故', 67),
#  ('大', 57),
#  ('知', 56),
#  ('善', 50),
#  ('于', 48),
#  ('德', 47),
#  ('若', 46),
#  ('也', 41),
#  ('生', 36),
#  ('可', 35),
#  ('？', 35),
#  ('物', 34),
#  ('民', 32),
#  ('则', 32),
#  ('自', 32),
#  ('谓', 31),
#  ('得', 31),
#  ('能', 31),
#  ('圣', 30),
#  ('夫', 30),
#  ('三', 29),
#  ('兮', 29),
#  ('常', 28),
#  ('所', 26),
#  ('一', 23),
#  ('欲', 23),
#  ('身', 23),
#  ('将', 23),
#  ('名', 22),
#  ('用', 22),
#  ('吾', 22),
#  ('二', 21),
#  ('事', 21),
#  ('强', 21),
#  ('四', 21),
#  ('五', 21),
#  ('足', 21),
#  ('言', 20),
#  ('贵', 20),
#  ('莫', 20),
#  ('曰', 20),
#  ('成', 19),
#  ('行', 19),
#  ('六', 19),
#  ('我', 19),
#  ('万', 18),
#  ('或', 18),
#  ('地', 18),
#  ('死', 18),
# ...

# %%
# Compare character counts across the two texts
sorted_chars_compare = []

characters = [char for char, count in sorted_chars if char in meaningful_list]
for char in meaningful_list:
    for pair in sorted_chars:
        if pair[0] == char:
            cnt_updated = pair[1]
            break

    for pair in sorted_chars_std:
        if pair[0] == char:
            cnt_std = pair[1]
            break

    diff = cnt_updated - cnt_std

    # Append the character and the difference in counts
    sorted_chars_compare.append((char, cnt_updated, cnt_std, diff))

# Sort by frequency in descending order
sorted_chars_compare.sort(key=lambda x: x[1], reverse=True)

sorted_chars_compare
# Out:
# [('为', 114, 113, 1),
#  ('无', 100, 101, -1),
#  ('天', 92, 92, 0),
#  ('人', 85, 85, 0),
#  ('有', 81, 83, -2),
#  ('下', 80, 82, -2),
#  ('道', 75, 76, -1),
#  ('大', 57, 58, -1),
#  ('知', 56, 59, -3),
#  ('德', 47, 44, 3),
#  ('生', 36, 38, -2),
#  ('自', 32, 33, -1),
#  ('民', 32, 33, -1),
#  ('圣', 30, 33, -3),
#  ('常', 28, 30, -2),
#  ('死', 18, 18, 0),
#  ('地', 18, 18, 0),
#  ('王', 10, 13, -3)]

# %%
import numpy as np
import matplotlib.pyplot as plt

# Extract data from sorted_chars_compare
chars = [x[0] for x in sorted_chars_compare]
cnt_updated = np.array([x[1] for x in sorted_chars_compare])
cnt_std = np.array([x[2] for x in sorted_chars_compare])

# Create figure and axis
fig, ax = plt.subplots(figsize=(6, 10), dpi=300)

# Calculate the minimum values for overlap
overlap = np.minimum(cnt_updated, cnt_std)
diff_positive = np.maximum(cnt_updated - cnt_std, 0)  # Green areas
diff_negative = np.maximum(cnt_std - cnt_updated, 0)  # Red areas

# Show the number of occurrences next to each bar
for i in range(len(chars)):
    plt.text(max(cnt_updated[i], cnt_std[i]) + 1, i, str(cnt_updated[i]), va='center', fontsize=12, fontfamily='Georgia', color='black')
# Create the stacked horizontal bar chart
ax.barh(chars, overlap, color='teal', label='Characters Occurring in Both Texts')
ax.barh(chars, diff_negative, left=overlap, color='#d3696d', label='Characters Occurring in Standard Text Only')
ax.barh(chars, diff_positive, left=overlap + diff_negative, color='#31c848', label='Characters Occurring in Mawangdui Text Only')

plt.title('Character Frequency', fontsize=14, fontweight='bold', fontfamily='Georgia', pad=80)
# plt.ylabel('Characters', fontsize=14, fontfamily='Georgia')
# plt.xlabel('Number of Occurrences', fontsize=14, fontfamily='Georgia')

plt.yticks(fontsize=14)
plt.xticks(fontsize=14)

plt.gca().axes.get_xaxis().set_visible(False)
plt.gca().set_ylim(-0.5, len(chars) - 0.5)
plt.gca().invert_yaxis()
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['bottom'].set_visible(False)

# Position legend below title and above plot
ax.legend(prop={'family': 'Georgia', 'size': 14},
          loc='lower center',
          bbox_to_anchor=(0.5, 1.01),
          ncol=1,
          borderaxespad=0.)

# Adjust layout to prevent label cutoff
plt.tight_layout()
plt.show()
